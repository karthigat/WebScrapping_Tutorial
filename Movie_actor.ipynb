# %%
# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install requests==2.26.0
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# ...

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Mohan_(actor)"

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %%
table = soup.find_all('table') # in html table is represented by the tag <table>

# %%
mohan_data = pd.DataFrame(columns=["Movie", "Year", "Role", "Langugae", "Link"])

for row in table[3].tbody.find_all(name=["tr"]):
    col = row.find_all("td")
    if (col != []):
        year = col[0].text
        movie = col[1].text
        get_link = col[1].find('a', href=True)
        if get_link is not None:
            link = get_link.get('href')
        role = col[2].text.strip()
        language = col[3].text.strip()
        mohan_data = mohan_data.append({"Movie":movie, "Year":year, "Role":role, "Langugae":language, "Link":link}, ignore_index=True)
# Out:
#                       Movie  Year                  Role   Langugae  \
# 0                    Kokila  1977                Baskar    Kannada
# 1                Aparichita  1978                 Shamu    Kannada
# 2                 Madaalasa  1978               Chandru  Malayalam
# 3    Bhoolokadalli Yamaraja  1979                Suresh    Kannada
# 4        Toorpu Velle Railu  1979              Raamanna     Telugu
# ..                      ...   ...                   ...        ...
# 100      Anbulla Kadhalukku  1999                  Prem      Tamil
# 101            Sutta Pazham  2008    Nandakumar (Nandu)      Tamil
# 102               Ghauttham  2009              Raghuram    Kannada
# 103        Abbayitho Ammayi  2016         Abhi's father     Telugu
# 104                   Haraa  2023  Ram / Dawood Ibrahim      Tamil
#
#                              Link
# 0        /wiki/Kokila_(1977_film)
# 1                /wiki/Aparichita
# 2                 /wiki/Madaalasa
# ...

# %%
mohan_data = pd.DataFrame(columns=["Movie", "Year", "Role", "Langugae", "Link"])

for row in table[3].tbody.find_all(name=["tr"]):
    col = row.find_all("td")
    if (col != []):
        year = col[0].text
        movie = col[1].text
        get_link = col[1].find('a', href=True)
        if get_link is not None:
            link = get_link.get('href')
        role = col[2].text.strip()
        language = col[3].text.strip()
        mohan_data = mohan_data.append({"Movie":movie, "Year":year, "Role":role, "Langugae":language, "Link":link}, ignore_index=True)

# %%
pd.read_html(str(table[3]), flavor='bs4')[0]
# Out:
#      Year                    Film                  Role   Language  \
# 0    1977                  Kokila                Baskar    Kannada
# 1    1978              Aparichita                 Shamu    Kannada
# 2    1978               Madaalasa               Chandru  Malayalam
# 3    1979  Bhoolokadalli Yamaraja                Suresh    Kannada
# 4    1979      Toorpu Velle Railu              Raamanna     Telugu
# ..    ...                     ...                   ...        ...
# 100  1999      Anbulla Kadhalukku                  Prem      Tamil
# 101  2008            Sutta Pazham    Nandakumar (Nandu)      Tamil
# 102  2009               Ghauttham              Raghuram    Kannada
# 103  2016        Abbayitho Ammayi         Abhi's father     Telugu
# 104  2023                   Haraa  Ram / Dawood Ibrahim      Tamil
#
#              Notes
# 0      Debut movie
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# ...
